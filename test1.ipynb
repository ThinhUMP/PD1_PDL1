# %%
import pandas as pd
gnina_cnn = pd.read_csv("./Data/gnina_cnn_screen.csv")
df_ann = pd.read_csv("./Data/df_screen_ann.csv")
df_simi = pd.read_csv("./Data/simi_screen.csv")

# %%
import pandas as pd
gnina_ann_df = pd.merge(gnina_cnn, df_ann, left_on='0', right_on='ID')
gnina_ann_df.shape
# Out:
# (22, 12)

# %%
merged_df = pd.merge(gnina_ann_df, df_simi, left_on='Name', right_on='Name')
merged_df.shape
# Out:
# (22, 16)

# %%
merged_df = merged_df[['ID','Name', 'StandardSmiles_x', 'Proba', 'gnina_CNN_best', 'tanimoto_avalon']]
merged_df.gnina_CNN_best = merged_df.gnina_CNN_best * -1

# %%
df_sorted = merged_df.sort_values('gnina_CNN_best', ascending=False)
df_sorted
# Out:
#             ID                                               Name  \
# 16   screen_75  1-(5-Carboxypentyl)-5-[(2,6-Dichlorobenzyl)Oxy...
# 0   screen_101                                         Vadadustat
# 6    screen_22                                         Fradafiban
# 20   screen_94  2-[2-(1,3-Dioxo-1,3-Dihydro-2h-Isoindol-2-Yl)E...
# 12   screen_60                                           Ecgonine
# 10   screen_56                                        Ceralifimod
# 4   screen_110                                              RB106
# 14   screen_69                                           ORE-1001
# 1   screen_103                                          Imidapril
# 9    screen_51                                          Zomepirac
# 21   screen_95  2-[4-[(Z)-2-Acetamido-3-oxo-3-[[(3S)-2-oxo-1-[...
# 5   screen_116  N-({6-[(4-CYANO-2-FLUOROBENZYL)OXY]NAPHTHALEN-...
# 7    screen_37                                          GW-559090
# 17   screen_76  Cp403700, (S)-1-{2-[(5-Chloro-1h-Indole-2-Carb...
# 11   screen_57                                            FG-2216
# 13   screen_65                                        Candoxatril
# 3    screen_11  (3S)-1-(4-acetylphenyl)-5-oxopyrrolidine-3-car...
# 2   screen_104                                         Ramiprilat
# 8    screen_42  (2R,4S)-2-[(1R)-1-{[(2R)-2-Amino-2-(4-hydroxyp...
# 18   screen_89                                            ROX-888
# 19   screen_90                                          Ketorolac
# 15   screen_74                                        Enalaprilat
#
#                                      StandardSmiles_x      Proba  \
# 16  O=C(O)CCCCCn1c(C(=O)O)cc2cc(OCc3c(Cl)cccc3Cl)c...  60.200000
# 0               O=C(O)CNC(=O)c1ncc(-c2cccc(Cl)c2)cc1O  52.899998
# 6   N=C(N)c1ccc(-c2ccc(OC[C@@H]3CC(CC(=O)O)C(=O)N3...  69.700005
# 20  CCOc1ccc(-c2ccc(C(=O)CC(CCN3C(=O)c4ccccc4C3=O)...  54.100002
# 12                      CN1C2CCC1C(C(=O)O)[C@@H](O)C2  64.500000
# 10  CCCc1ccc(COc2ccc3c(c2)CCC(CN2CC(C(=O)O)C2)=C3C...  64.700005
# 4   O=C(NCC(=O)N1C(C(=O)O)CC[C@@H]1c1ccccc1)C(S)Cc...  52.000000
# 14  CC(C)CC(NC(Cc1cncn1Cc1cc(Cl)cc(Cl)c1)C(=O)O)C(...  62.500000
# 1   CCOC(=O)C(CCc1ccccc1)NC(C)C(=O)N1C(=O)N(C)CC1C...  52.399998
# 9               Cc1cc(CC(=O)O)n(C)c1C(=O)c1ccc(Cl)cc1  65.000000
# 21  CC(=O)N=C(Cc1ccc(CC(=O)O)c(C=O)c1)C(=O)NC1CCCC...  53.800000
# 5   N#Cc1ccc(COc2ccc3cc(S(=O)(=O)NC(CCC(=O)O)C(=O)...  50.500000
# 7   Cc1ccccc1OCC(=O)NC(CC(C)C)C(=O)NC(Cc1ccc(OC(=O...  67.299995
# 17  O=C(NC(Cc1ccccc1)C(=O)N1CC(C(=O)O)C1)c1cc2cc(C...  60.100002
# 11                   O=C(O)CNC(=O)c1nc(Cl)c2ccccc2c1O  64.600006
# 13  COCCOCC(CC1(C(=O)NC2CCC(C(=O)O)CC2)CCCC1)C(=O)...  63.600000
# 3                   CC(=O)c1ccc(N2CC(C(=O)O)CC2=O)cc1  70.500000
# 2   CC(NC(CCc1ccccc1)C(=O)O)C(=O)N1C(C(=O)O)C[C@@H...  52.399998
# 8   CC1(C)S[C@H](C(C=O)NC(=O)C(N)c2ccc(O)cc2)NC1C(...  66.100000
# 18                    O=C(c1ccccc1)c1ccc2n1CCC2C(=O)O  56.100000
# 19                    O=C(c1ccccc1)c1ccc2n1CCC2C(=O)O  56.100000
# 15         CC(NC(CCc1ccccc1)C(=O)O)C(=O)N1CCCC1C(=O)O  60.500000
#
#     gnina_CNN_best  tanimoto_avalon
# 16            0.94         0.372881
# 0             0.91         0.322097
# 6             0.89         0.341463
# 20            0.88         0.390845
# 12            0.88         0.371134
# 10            0.86         0.348993
# 4             0.86         0.418251
# 14            0.85         0.366279
# 1             0.84         0.356364
# 9             0.84         0.335347
# 21            0.83         0.353147
# 5             0.83         0.323432
# 7             0.82         0.380623
# 17            0.81         0.329897
# 11            0.81         0.321555
# 13            0.79         0.337931
# 3             0.79         0.353160
# 2             0.78         0.364217
# 8             0.76         0.329577
# 18            0.76         0.353247
# 19            0.76         0.353247
# 15            0.75         0.368852

# %%
df_sorted[df_sorted['Proba']>=70]
# Out:
#           ID                                               Name  \
# 3  screen_11  (3S)-1-(4-acetylphenyl)-5-oxopyrrolidine-3-car...
#
#                     StandardSmiles_x  Proba  gnina_CNN_best  tanimoto_avalon
# 3  CC(=O)c1ccc(N2CC(C(=O)O)CC2=O)cc1   70.5            0.79          0.35316

# %%
df_sorted
# Out:
#             ID                                               Name  \
# 16   screen_75  1-(5-Carboxypentyl)-5-[(2,6-Dichlorobenzyl)Oxy...
# 0   screen_101                                         Vadadustat
# 6    screen_22                                         Fradafiban
# 20   screen_94  2-[2-(1,3-Dioxo-1,3-Dihydro-2h-Isoindol-2-Yl)E...
# 12   screen_60                                           Ecgonine
# 10   screen_56                                        Ceralifimod
# 4   screen_110                                              RB106
# 14   screen_69                                           ORE-1001
# 1   screen_103                                          Imidapril
# 9    screen_51                                          Zomepirac
# 21   screen_95  2-[4-[(Z)-2-Acetamido-3-oxo-3-[[(3S)-2-oxo-1-[...
# 5   screen_116  N-({6-[(4-CYANO-2-FLUOROBENZYL)OXY]NAPHTHALEN-...
# 7    screen_37                                          GW-559090
# 17   screen_76  Cp403700, (S)-1-{2-[(5-Chloro-1h-Indole-2-Carb...
# 11   screen_57                                            FG-2216
# 13   screen_65                                        Candoxatril
# 3    screen_11  (3S)-1-(4-acetylphenyl)-5-oxopyrrolidine-3-car...
# 2   screen_104                                         Ramiprilat
# 8    screen_42  (2R,4S)-2-[(1R)-1-{[(2R)-2-Amino-2-(4-hydroxyp...
# 18   screen_89                                            ROX-888
# 19   screen_90                                          Ketorolac
# 15   screen_74                                        Enalaprilat
#
#                                      StandardSmiles_x      Proba  \
# 16  O=C(O)CCCCCn1c(C(=O)O)cc2cc(OCc3c(Cl)cccc3Cl)c...  60.200000
# 0               O=C(O)CNC(=O)c1ncc(-c2cccc(Cl)c2)cc1O  52.899998
# 6   N=C(N)c1ccc(-c2ccc(OC[C@@H]3CC(CC(=O)O)C(=O)N3...  69.700005
# 20  CCOc1ccc(-c2ccc(C(=O)CC(CCN3C(=O)c4ccccc4C3=O)...  54.100002
# 12                      CN1C2CCC1C(C(=O)O)[C@@H](O)C2  64.500000
# 10  CCCc1ccc(COc2ccc3c(c2)CCC(CN2CC(C(=O)O)C2)=C3C...  64.700005
# 4   O=C(NCC(=O)N1C(C(=O)O)CC[C@@H]1c1ccccc1)C(S)Cc...  52.000000
# 14  CC(C)CC(NC(Cc1cncn1Cc1cc(Cl)cc(Cl)c1)C(=O)O)C(...  62.500000
# 1   CCOC(=O)C(CCc1ccccc1)NC(C)C(=O)N1C(=O)N(C)CC1C...  52.399998
# 9               Cc1cc(CC(=O)O)n(C)c1C(=O)c1ccc(Cl)cc1  65.000000
# 21  CC(=O)N=C(Cc1ccc(CC(=O)O)c(C=O)c1)C(=O)NC1CCCC...  53.800000
# 5   N#Cc1ccc(COc2ccc3cc(S(=O)(=O)NC(CCC(=O)O)C(=O)...  50.500000
# 7   Cc1ccccc1OCC(=O)NC(CC(C)C)C(=O)NC(Cc1ccc(OC(=O...  67.299995
# 17  O=C(NC(Cc1ccccc1)C(=O)N1CC(C(=O)O)C1)c1cc2cc(C...  60.100002
# 11                   O=C(O)CNC(=O)c1nc(Cl)c2ccccc2c1O  64.600006
# 13  COCCOCC(CC1(C(=O)NC2CCC(C(=O)O)CC2)CCCC1)C(=O)...  63.600000
# 3                   CC(=O)c1ccc(N2CC(C(=O)O)CC2=O)cc1  70.500000
# 2   CC(NC(CCc1ccccc1)C(=O)O)C(=O)N1C(C(=O)O)C[C@@H...  52.399998
# 8   CC1(C)S[C@H](C(C=O)NC(=O)C(N)c2ccc(O)cc2)NC1C(...  66.100000
# 18                    O=C(c1ccccc1)c1ccc2n1CCC2C(=O)O  56.100000
# 19                    O=C(c1ccccc1)c1ccc2n1CCC2C(=O)O  56.100000
# 15         CC(NC(CCc1ccccc1)C(=O)O)C(=O)N1CCCC1C(=O)O  60.500000
#
#     gnina_CNN_best  tanimoto_avalon
# 16            0.94         0.372881
# 0             0.91         0.322097
# 6             0.89         0.341463
# 20            0.88         0.390845
# 12            0.88         0.371134
# 10            0.86         0.348993
# 4             0.86         0.418251
# 14            0.85         0.366279
# 1             0.84         0.356364
# 9             0.84         0.335347
# 21            0.83         0.353147
# 5             0.83         0.323432
# 7             0.82         0.380623
# 17            0.81         0.329897
# 11            0.81         0.321555
# 13            0.79         0.337931
# 3             0.79         0.353160
# 2             0.78         0.364217
# 8             0.76         0.329577
# 18            0.76         0.353247
# 19            0.76         0.353247
# 15            0.75         0.368852
